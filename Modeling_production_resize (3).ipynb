# %% [markdown]
# # Image resizing

# %%
from PIL import Image
import glob

# %%
image =Image.open(r"C:\Users\udaya\Downloads\A_Prod_P1\Input\input_p3.jpg") # paste the path of the image
size=image.size # the dimensions of the image is stored in size
print(size)
image#this will dispaly the image here
# Out:
# (720, 480)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x480 at 0x1B6DF974490>

# %%
image_resize = image.resize((224,224)) # this will resize the image we given into 224*224  
image_resize.save('Rainbow-Rose-resize12.jpg')#the resized image should be saved  here we provide the name to store it

print(image_resize.size)
# Out:
# (224, 224)

# %%
#we can include this line if we want to see the image 
image_resize
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1B6DF79F7C0>

# %%
print("Before resizing : image dimensions" , image.size)
print("After resizing : image dimensions " ,image_resize.size)
# Out:
# Before resizing : image dimensions (720, 480)
# After resizing : image dimensions  (224, 224)
